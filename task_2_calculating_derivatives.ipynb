# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sympy as smp
# %matplotlib inline

# %%
class DerivativeNum:
    
    def __init__(self, f, h):
        self.f = f
        self.h = h
        self.alpha = alpha
        self.dots = dots
    
    def __call__(self, x):
        der = 0
        for i, k in zip(self.alpha, self.dots):
            der = der + i*f(x+k*h)/h
        return der

# %%
class DerivativeNum1(DerivativeNum):
    def __init__(self, f, h):
        self.alpha = np.array([1.,-1.])
        self.dots = np.array([1., 0.])
        
class DerivativeNum2(DerivativeNum):
     def __init__(self, f, h):
        self.alpha = np.array([1.,-1.])
        self.dots = np.array([0., -1.])
        
class DerivativeNum3(DerivativeNum):
    def __init__(self, f, h):
        self.alpha = np.array([0.5,-0.5])
        self.dots = np.array([1., -1.])
        
class DerivativeNum4(DerivativeNum):
    def __init__(self, f, h):
        self.alpha = np.array([4/6, -4/6, -1/12, 1/12])
        self.dots = np.array([1., -1., 2., -2.])
        
class DerivativeNum6(DerivativeNum):
    def __init__(self, f, h):
        self.alpha = np.array([3/4, -3/4, -3/20, 3/20, 1/60, -1/60])
        self.dots = np.array([1., -1., 2., -2., 3., -3.])
        
class DerivativeNum7(DerivativeNum):
    def __init__(self, f, h):
        self.alpha = np.array([alpha1, alpha2, alpha3, alpha4, alpha5, alpha6 ])
        self.dots = np.array([dots1, dots2, dots3, dots4, dots5, dots6])

# %%
steps = [2**(-n+1) for n in range(1, 21)]
print('Шаги: ', steps)
# Out:
# Шаги:  [1, 0.5, 0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625, 0.001953125, 0.0009765625, 0.00048828125, 0.000244140625, 0.0001220703125, 6.103515625e-05, 3.0517578125e-05, 1.52587890625e-05, 7.62939453125e-06, 3.814697265625e-06, 1.9073486328125e-06]

# %%
x0 = 5
f = TestFunction1
TestFunction1 = lambda x: np.sin(x**2)
for h in steps:
            derivativeNum1 = DerivativeNum1(TestFunction1, h)
            derivativeNum2 = DerivativeNum2(TestFunction1, h)
            derivativeNum3 = DerivativeNum3(TestFunction1, h)
            derivativeNum4 = DerivativeNum4(TestFunction1, h)
            derivativeNum5 = DerivativeNum6(TestFunction1, h)
            
            
            


print(derivativeNum1(x0))
print(derivativeNum2(x0))
print(derivativeNum3(x0))
print(derivativeNum4(x0))
print(derivativeNum5(x0))
# Out:
# 9.912042630661745
# 9.912013605426182
# 9.912028118043963
# 9.912028118641501
# 9.912028118638773

# %%
TestFunction2 = lambda x: np.cos(np.sin(x))
f = TestFunction2
for h in steps:
            derivativeNum7 = DerivativeNum1(TestFunction2, h)
            derivativeNum8 = DerivativeNum2(TestFunction2, h)
            derivativeNum9 = DerivativeNum3(TestFunction2, h)
            derivativeNum10 = DerivativeNum4(TestFunction2, h)
            derivativeNum11 = DerivativeNum6(TestFunction2, h)
            


print(derivativeNum7(x0))
print(derivativeNum8(x0))
print(derivativeNum9(x0))
print(derivativeNum10(x0))
print(derivativeNum11(x0))
# Out:
# 0.2321992352954112
# 0.23219782626256347
# 0.23219853077898733
# 0.23219853077171138
# 0.23219853077807784

# %%
TestFunction3 = lambda x: np.exp(np.sin(np.cos(x)))
f = TestFunction3
for h in steps:
            derivativeNum12 = DerivativeNum1(TestFunction3, h)
            derivativeNum13 = DerivativeNum2(TestFunction3, h)
            derivativeNum14 = DerivativeNum3(TestFunction3, h)
            derivativeNum15 = DerivativeNum4(TestFunction3, h)
            derivativeNum16 = DerivativeNum6(TestFunction3, h)
            


print(derivativeNum12(x0))
print(derivativeNum13(x0))
print(derivativeNum14(x0))
print(derivativeNum15(x0))
print(derivativeNum16(x0))
# Out:
# 1.2179230424808338
# 1.2179222404956818
# 1.2179226414882578
# 1.2179226415173616
# 1.217922641468249

# %%
TestFunction4 = lambda x: np.log(x+3)
f = TestFunction4
for h in steps:
            derivativeNum17 = DerivativeNum1(TestFunction4, h)
            derivativeNum18 = DerivativeNum2(TestFunction4, h)
            derivativeNum19 = DerivativeNum3(TestFunction4, h)
            derivativeNum20 = DerivativeNum4(TestFunction4, h)
            derivativeNum21 = DerivativeNum6(TestFunction4, h)
            


print(derivativeNum17(x0))
print(derivativeNum18(x0))
print(derivativeNum19(x0))
print(derivativeNum20(x0))
print(derivativeNum21(x0))
# Out:
# 0.1249999850988388
# 0.1250000149011612
# 0.125
# 0.1250000000873115
# 0.1250000000181899

# %%
TestFunction5 = lambda x: np.sqrt(x+3)
f = TestFunction5
for h in steps:
            derivativeNum22 = DerivativeNum1(TestFunction5, h)
            derivativeNum23 = DerivativeNum2(TestFunction5, h)
            derivativeNum24 = DerivativeNum3(TestFunction5, h)
            derivativeNum25 = DerivativeNum4(TestFunction5, h)
            derivativeNum26 = DerivativeNum6(TestFunction5, h)
            


print(derivativeNum22(x0))
print(derivativeNum23(x0))
print(derivativeNum24(x0))
print(derivativeNum25(x0))
print(derivativeNum26(x0))
# Out:
# 0.17677668458782136
# 0.17677670600824058
# 0.17677669529803097
# 0.17677669529803097
# 0.17677669518161565

# %%
import sympy as smp
xSym = smp.Symbol('x')

# код для отображения формул в формате LaTex
smp.init_printing(use_latex='mathjax')
import IPython.display as ipy
functionsSymDerivative = [smp.cos(xSym**2)*2*xSym, -smp.sin(smp.sin(xSym))*smp.cos(xSym), -smp.exp(smp.sin(smp.cos(xSym)))*smp.cos(xSym)*smp.sin(xSym), 1/(xSym+3), 1/2*smp.sqrt(xSym+3) ]

FuncSymDerivative1 = smp.cos(xSym**2)*2*xSym 
FuncDerivative1 = smp.lambdify(xSym, FuncSymDerivative1)
FuncSymDerivative2 = -smp.sin(smp.sin(xSym))*smp.cos(xSym)
FuncDerivative2 = smp.lambdify(xSym, FuncSymDerivative2)
FuncSymDerivative3 = -smp.exp(smp.sin(smp.cos(xSym)))*smp.cos(xSym)*smp.sin(xSym)
FuncDerivative3 = smp.lambdify(xSym, FuncSymDerivative3)
FuncSymDerivative4 = 1/(xSym+3)
FuncDerivative4 = smp.lambdify(xSym, FuncSymDerivative4)
FuncSymDerivative5 = 1/2*(smp.sqrt(xSym+3))
FuncDerivative5 = smp.lambdify(xSym, FuncSymDerivative5)

x0 = 5
print(FuncDerivative1(x0))
print(FuncDerivative2(x0))
print(FuncDerivative3(x0))
print(FuncDerivative4(x0))
print(FuncDerivative5(x0))
# Out:
# 9.912028118634735
# 0.23219853078170197
# 0.35985969633914694
# 0.125
# 1.4142135623730951

# %%
import sympy as smp
xSym = smp.Symbol('x')

# код для отображения формул в формате LaTex
smp.init_printing(use_latex='mathjax')
import IPython.display as ipy
functionsSym = [smp.sin(xSym**2), smp.cos(smp.sin(xSym)), smp.exp(smp.sin(smp.cos(xSym))), smp.ln(xSym+3), smp.sqrt(xSym+3)]

FuncSym1 = smp.sin(xSym**2) 
Func1 = smp.lambdify(xSym, FuncSym1)
FuncSym2 = smp.cos(smp.sin(xSym)) 
Func2 = smp.lambdify(xSym, FuncSym2)
FuncSym3 = smp.exp(smp.sin(smp.cos(xSym)))
Func3 = smp.lambdify(xSym, FuncSym3)
FuncSym4 = smp.ln(xSym+3)
Func4 = smp.lambdify(xSym, FuncSym4)
FuncSym5 = smp.sqrt(xSym+3)
Func5 = smp.lambdify(xSym, FuncSym5)

functions = [smp.lambdify(xSym, f) for f in functionsSym]

# %%
derivativesAnalyticalSym = [smp.diff(f, xSym) for f in functionsSym]
ipy.display(derivativesAnalyticalSym)

# символьное дифференцирование; используем генераторы списков
derivativesAnalytical = [smp.lambdify(xSym, f) \
                        for f in derivativesAnalyticalSym]
ipy.display(derivativesAnalytical)
# Out:
# ⎡       ⎛ 2⎞                         sin(cos(x))                       1
# ⎢2⋅x⋅cos⎝x ⎠, -sin(sin(x))⋅cos(x), -ℯ           ⋅sin(x)⋅cos(cos(x)), ─────, ──
# ⎢                                                                    x + 3
# ⎣                                                                           2⋅
#
#    1     ⎤
# ─────────⎥
#   _______⎥
# ╲╱ x + 3 ⎦
# [<function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>]

# %%
h0 = 2**(-20)
derivativesNum = []

for f in functions:
    derivativesNum.append(DerivativeNum1(f, h0))
    
    

    

ipy.display(functionsSym, functions, derivativesNum)
#print(symbolicFunctions, '\n\n', functions)
# Out:
# ⎡   ⎛ 2⎞                sin(cos(x))                _______⎤
# ⎣sin⎝x ⎠, cos(sin(x)), ℯ           , log(x + 3), ╲╱ x + 3 ⎦
# [<function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>,
#  <function _lambdifygenerated(x)>]
# ...

# %%
xLeft, xRight = 0., 10.
numPoints = 100
xData = np.linspace(xLeft, xRight, numPoints)
figureSizeConst = (13, 6.7)

# %%
plt.figure(figsize=figureSizeConst)
plt.title('Анализ сходимости')


for f, dfdx in zip(functions, derivativesAnalytical):
        
        errors = []
        
        for h in steps:
            dfdxNum = DerivativeNum1(f, h)
            
            
            
            error = np.fabs(dfdxNum(x0) - dfdx(x0))
            
            errors.append(error)
        
        print(errors, '\n')
          
        # на каждой итерации, построение графика в ОДНОМ окне, созданном plt.figure() выше
        plt.loglog(steps, errors, '-o', linewidth=4, markersize=10)
        

plt.xlabel('Шаг сетки')
plt.ylabel('Погрешность')
plt.show()
# Out:
# [10.771455221980078, 11.485632006846345, 6.769727435960267, 1.6081035868966893, 0.1774959420458373, 0.07532319526989895, 0.07852730528143326, 0.04939451586277066, 0.027215222845805798, 0.014235009640865215, 0.007274077327467765, 0.0036761462006911216, 0.0018478454761083896, 0.0009263652647764076, 0.00046379319286593557, 0.00023204922803365946, 0.00011606277115738806, 5.8040923649471665e-05, 2.9022847629178727e-05, 1.4512027009416784e-05]
#
# [0.1546173945316429, 0.14152229353767617, 0.08317628798716967, 0.04408799309101194, 0.02259079999229527, 0.011422304155327717, 0.005741654794185175, 0.002878300309475529, 0.0014409992981111175, 0.0007209595500082544, 0.0003605944521179738, 0.0001803258580959921, 9.017008234443735e-05, 4.5086828336232676e-05, 2.2543860736939925e-05, 1.1272041788495946e-05, 5.636048640761393e-06, 2.8180338770000812e-06, 1.4090010292677757e-06, 7.045137092320797e-07]
#
# ...

# %%
plt.figure(figsize=figureSizeConst)
plt.title('Анализ сходимости')


for f, dfdx in zip(functions, derivativesAnalytical):
        
        errors = []
        
        for h in steps:
            dfdxNum = DerivativeNum2(f, h)
            
            
            
            error = np.fabs(dfdxNum(x0) - dfdx(x0))
            
            errors.append(error)
        
        print(errors, '\n')
          
        # на каждой итерации, построение графика в ОДНОМ окне, созданном plt.figure() выше
        plt.loglog(steps, errors, '-o', linewidth=4, markersize=10)
        

plt.xlabel('Шаг сетки')
plt.ylabel('Погрешность')
plt.show()
# Out:
# [9.756476552067443, 12.147781841960521, 8.278357832919538, 3.1362115570462104, 1.0786200891533486, 0.39387471795230944, 0.15845015269066565, 0.06939307438471154, 0.032215978460156336, 0.015485268302311894, 0.007586646352818249, 0.003754288729508559, 0.0018673811253488992, 0.0009312491779933652, 0.0004650141714233058, 0.0002323544718461079, 0.00011613908242047444, 5.8060000410975476e-05, 2.9027616220034247e-05, 1.451320855316851e-05]
#
# [0.3848327827565804, 0.20154092531098114, 0.09818408704792284, 0.04783717198499318, 0.023527872599681393, 0.011656557650056604, 0.005800217239653099, 0.0028929408626371667, 0.0014446594327783002, 0.0007218745834482176, 0.00036082321058508726, 0.00018038304777726055, 9.018437957344916e-05, 4.509040353220528e-05, 2.2544755652026405e-05, 1.1272265496492517e-05, 5.6361050017328385e-06, 2.8180393062682274e-06, 1.4090355623663786e-06, 7.045191385002258e-07]
#
# ...

# %%
plt.figure(figsize=figureSizeConst)
plt.title('Анализ сходимости')


for f, dfdx in zip(functions, derivativesAnalytical):
        
        errors = []
        
        for h in steps:
            dfdxNum = DerivativeNum3(f, h)
            
            
            
            error = np.fabs(dfdxNum(x0) - dfdx(x0))
            
            errors.append(error)
        
        print(errors, '\n')
          
        # на каждой итерации, построение графика в ОДНОМ окне, созданном plt.figure() выше
        plt.loglog(steps, errors, '-o', linewidth=4, markersize=10)
        

plt.xlabel('Шаг сетки')
plt.ylabel('Погрешность')
plt.show()
# Out:
# [10.26396588702376, 11.816706924403432, 7.524042634439903, 2.3721575719714494, 0.6280580155995938, 0.15927576134120613, 0.039961423704616195, 0.00999927926097044, 0.002500377807175269, 0.0006251293307233396, 0.00015628451267524213, 3.9071264408718775e-05, 9.767824620254828e-06, 2.4419566084787903e-06, 6.104892786851224e-07, 1.5262190622422622e-07, 3.8155631543190793e-08, 9.538380751905606e-09, 2.3842954277597528e-09, 5.907718758635383e-10]
#
# [0.11510769411246877, 0.030009315886652482, 0.007503899530376584, 0.001874589446990621, 0.0004685363036930623, 0.00011712674736444328, 2.9281222733962275e-05, 7.320276580818907e-06, 1.8300673335913675e-06, 4.57516719981621e-07, 1.143792335567273e-07, 2.8594840634221796e-08, 7.148614505902984e-09, 1.7875979863024583e-09, 4.474575432400485e-10, 1.1185399828583797e-10, 2.8180485722728577e-11, 2.714634073086586e-12, 1.7266549301453438e-11, 2.714634073086586e-12]
#
# ...

# %%
plt.figure(figsize=figureSizeConst)
plt.title('Анализ сходимости')


for f, dfdx in zip(functions, derivativesAnalytical):
        
        errors = []
        
        for h in steps:
            dfdxNum = DerivativeNum4(f, h)
            
            
            
            error = np.fabs(dfdxNum(x0) - dfdx(x0))
            
            errors.append(error)
        
        print(errors, '\n')
          
        # на каждой итерации, построение графика в ОДНОМ окне, созданном plt.figure() выше
        plt.loglog(steps, errors, '-o', linewidth=4, markersize=10)
        

plt.xlabel('Шаг сетки')
plt.ylabel('Погрешность')
plt.show()
# Out:
# [10.267455881653333, 12.334287270196656, 6.093154537785393, 0.6548625511486339, 0.046691496808973554, 0.003015009921744749, 0.00018997782575347344, 1.1897779755187798e-05, 7.439892453220409e-07, 4.6505238771032964e-08, 2.9066544726674692e-09, 1.816413686128726e-10, 1.1359801987964602e-11, 5.666578317686799e-13, 2.540190280342358e-13, 5.702105454474804e-13, 5.098144129078719e-13, 1.723066134218243e-13, 1.7639223415244487e-12, 6.766143201275554e-12]
#
# [0.05955884216060883, 0.0016431898113804522, 2.094078284525791e-06, 1.8472474713482345e-06, 1.4807740641997746e-07, 9.77141109692603e-09, 6.188108636617784e-10, 3.880326615579577e-11, 2.4154844791013375e-12, 1.7016943409942087e-13, 5.720424134381119e-14, 8.56259507742152e-14, 1.457167719820518e-14, 5.545841563758813e-13, 4.408973186542653e-13, 6.682709940974974e-13, 1.3503920204271935e-12, 1.0927786453507338e-11, 1.3628570494361725e-11, 9.990591687270012e-12]
#
# ...

# %%
plt.figure(figsize=figureSizeConst)
plt.title('Анализ сходимости')


for f, dfdx in zip(functions, derivativesAnalytical):
        
        errors = []
        
        for h in steps:
            dfdxNum = DerivativeNum6(f, h)
            
            
            
            error = np.fabs(dfdxNum(x0) - dfdx(x0))
            
            errors.append(error)
        
        print(errors, '\n')
          
        # на каждой итерации, построение графика в ОДНОМ окне, созданном plt.figure() выше
        plt.loglog(steps, errors, '-o', linewidth=4, markersize=10)
        

plt.xlabel('Шаг сетки')
plt.ylabel('Погрешность')
plt.show()
# Out:
# [10.20710695829301, 12.580412589858751, 5.073548721722868, 0.1874252042143656, 0.003570445116285015, 5.8539159971005006e-05, 9.256600339568877e-07, 1.4506586154539036e-08, 2.2682833389353618e-10, 3.5473846082823e-12, 5.861977570020827e-14, 3.019806626980426e-14, 3.375077994860476e-14, 1.580957587066223e-13, 3.8902214782865485e-13, 6.696865284538944e-13, 8.22453216642316e-13, 1.687538997430238e-13, 1.191935439237568e-12, 4.037659095956769e-12]
#
# [0.027913411133798416, 0.002092353903793004, 6.696788683618893e-05, 1.2158915462801012e-06, 1.969073334939786e-08, 3.1040006676086307e-10, 4.859751490116082e-12, 7.624456621613263e-14, 5.689893001203927e-15, 9.242606680004428e-15, 6.253331186201194e-14, 2.806088694740083e-14, 1.9148571617222387e-13, 9.382772336863354e-13, 1.5668022435022522e-13, 1.2753686995381486e-13, 2.60094723536497e-12, 5.925565593756232e-12, 1.9995033406772222e-11, 3.624128774859514e-12]
#
# ...
